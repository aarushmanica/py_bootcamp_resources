# %% [markdown]
# ## Python Image Exercise

# %%
from PIL import Image

# %%
words = Image.open('word_matrix.png')

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x7FC1BDF46130>

# %%
mask = Image.open('mask.png')

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x7FC1BE03F190>

# %%
words.size
# Out:
# (1015, 559)

# %%
mask.size
# Out:
# (505, 251)

# %%
mask = mask.resize((1015, 559))

# %%
mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x7FC1BE105A30>

# %%
mask.putalpha(199)

# %%
mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x7FC1BE105A30>

# %%
words.paste(mask, (0, 0), mask)

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x7FC1BDF46130>
